# %% [markdown]
# ## Analysing channel flow data

# %%
import xarray
import matplotlib.pyplot as plt
import seaborn
import numpy as np
import scipy

# %%
file_name = 'inner10_outer_10_000'
ds = xarray.open_dataset(f'./datasets/'+ file_name +'.nc', chunks={'time': '100MB'})

# %%
ds = ds.isel(sample=0)

# %%
outer_steps = len(ds.time)

# %%
total_sim_time = max(ds.time.values)

# %%
def vx_at_x_upper_boundary(ds):
  return ds.u.isel(x=-1)  # slice operator

p = ds.pipe(vx_at_x_upper_boundary).plot(hue='time')
# Out:
# /rds/general/user/dd519/home/anaconda3/envs/PNAS_codes/lib/python3.10/site-packages/IPython/core/events.py:89: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   func(*args, **kwargs)
# /rds/general/user/dd519/home/anaconda3/envs/PNAS_codes/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
# Error in callback <function flush_figures at 0x147c9bf025f0> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/anaconda3/envs/PNAS_codes/lib/python3.10/site-packages/matplotlib_inline/backend_inline.py:126, in flush_figures()
#     123 if InlineBackend.instance().close_figures:
#     124     # ignore the tracking, just draw and close all figures
#     125     try:
# --> 126         return show(True)
#     127     except Exception as e:
#     128         # safely show traceback if in IPython, else raise
#     129         ip = get_ipython()
#
# File ~/anaconda3/envs/PNAS_codes/lib/python3.10/site-packages/matplotlib_inline/backend_inline.py:90, in show(close, block)
#      88 try:
#      89     for figure_manager in Gcf.get_all_fig_managers():
# ---> 90         display(
#      91             figure_manager.canvas.figure,
#      92             metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      93         )
#      94 finally:
#      95     show._to_draw = []
#
# File ~/anaconda3/envs/PNAS_codes/lib/python3.10/site-packages/IPython/core/display_functions.py:298, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     296     publish_display_data(data=obj, metadata=metadata, **kwargs)
#     297 else:
# --> 298     format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     299     if not format_dict:
#     300         # nothing to display (e.g. _ipython_display_ took over)
#     301         continue
#
# File ~/anaconda3/envs/PNAS_codes/lib/python3.10/site-packages/IPython/core/formatters.py:177, in DisplayFormatter.format(self, obj, include, exclude)
#     175 md = None
#     176 try:
# --> 177     data = formatter(obj)
#     178 except:
#     179     # FIXME: log the exception
#     180     raise
#
# File ~/anaconda3/envs/PNAS_codes/lib/python3.10/site-packages/decorator.py:232, in decorate.<locals>.fun(*args, **kw)
#     230 if not kwsyntax:
#     231     args, kw = fix(args, kw, sig)
# --> 232 return caller(func, *(extras + args), **kw)
#
# File ~/anaconda3/envs/PNAS_codes/lib/python3.10/site-packages/IPython/core/formatters.py:221, in catch_format_error(method, self, *args, **kwargs)
#     219 """show traceback on failed format call"""
#     220 try:
# --> 221     r = method(self, *args, **kwargs)
#     222 except NotImplementedError:
#     223     # don't warn on NotImplementedErrors
#     224     return self._check_return(None, args[0])
#
# File ~/anaconda3/envs/PNAS_codes/lib/python3.10/site-packages/IPython/core/formatters.py:338, in BaseFormatter.__call__(self, obj)
#     336     pass
#     337 else:
# --> 338     return printer(obj)
#     339 # Finally look for special method names
#     340 method = get_real_method(obj, self.print_method)
#
# File ~/anaconda3/envs/PNAS_codes/lib/python3.10/site-packages/IPython/core/pylabtools.py:152, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149     from matplotlib.backend_bases import FigureCanvasBase
#     150     FigureCanvasBase(fig)
# --> 152 fig.canvas.print_figure(bytes_io, **kw)
#     153 data = bytes_io.getvalue()
#     154 if fmt == 'svg':
#
# File ~/anaconda3/envs/PNAS_codes/lib/python3.10/site-packages/matplotlib/backend_bases.py:2318, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2316 if bbox_inches:
#    2317     if bbox_inches == "tight":
# -> 2318         bbox_inches = self.figure.get_tightbbox(
#    2319             renderer, bbox_extra_artists=bbox_extra_artists)
#    2320         if pad_inches is None:
#    2321             pad_inches = rcParams['savefig.pad_inches']
#
# File ~/anaconda3/envs/PNAS_codes/lib/python3.10/site-packages/matplotlib/figure.py:1734, in FigureBase.get_tightbbox(self, renderer, bbox_extra_artists)
#    1731     artists = bbox_extra_artists
#    1733 for a in artists:
# -> 1734     bbox = a.get_tightbbox(renderer)
#    1735     if bbox is not None:
#    1736         bb.append(bbox)
#
# File ~/anaconda3/envs/PNAS_codes/lib/python3.10/site-packages/matplotlib/axes/_base.py:4451, in _AxesBase.get_tightbbox(self, renderer, call_axes_locator, bbox_extra_artists, for_layout_only)
#    4448     bbox_artists = self.get_default_bbox_extra_artists()
#    4450 for a in bbox_artists:
# -> 4451     bbox = a.get_tightbbox(renderer)
#    4452     if (bbox is not None
#    4453             and 0 < bbox.width < np.inf
#    4454             and 0 < bbox.height < np.inf):
#    4455         bb.append(bbox)
#
# File ~/anaconda3/envs/PNAS_codes/lib/python3.10/site-packages/matplotlib/legend.py:939, in Legend.get_tightbbox(self, renderer)
#     937 def get_tightbbox(self, renderer=None):
#     938     # docstring inherited
# --> 939     return self._legend_box.get_window_extent(renderer)
#
# File ~/anaconda3/envs/PNAS_codes/lib/python3.10/site-packages/matplotlib/offsetbox.py:353, in OffsetBox.get_window_extent(self, renderer)
#     351 if renderer is None:
#     352     renderer = self.figure._get_renderer()
# --> 353 w, h, xd, yd, offsets = self.get_extent_offsets(renderer)
#     354 px, py = self.get_offset(w, h, xd, yd, renderer)
#     355 return mtransforms.Bbox.from_bounds(px - xd, py - yd, w, h)
#
# File ~/anaconda3/envs/PNAS_codes/lib/python3.10/site-packages/matplotlib/offsetbox.py:435, in VPacker.get_extent_offsets(self, renderer)
#     432         if isinstance(c, PackerBase) and c.mode == "expand":
#     433             c.set_width(self.width)
# --> 435 whd_list = [c.get_extent(renderer)
#     436             for c in self.get_visible_children()]
#     437 whd_list = [(w, h, xd, (h - yd)) for w, h, xd, yd in whd_list]
#     439 wd_list = [(w, xd) for w, h, xd, yd in whd_list]
#
# File ~/anaconda3/envs/PNAS_codes/lib/python3.10/site-packages/matplotlib/offsetbox.py:435, in <listcomp>(.0)
#     432         if isinstance(c, PackerBase) and c.mode == "expand":
#     433             c.set_width(self.width)
# --> 435 whd_list = [c.get_extent(renderer)
#     436             for c in self.get_visible_children()]
#     437 whd_list = [(w, h, xd, (h - yd)) for w, h, xd, yd in whd_list]
#     439 wd_list = [(w, xd) for w, h, xd, yd in whd_list]
#
# File ~/anaconda3/envs/PNAS_codes/lib/python3.10/site-packages/matplotlib/offsetbox.py:346, in OffsetBox.get_extent(self, renderer)
#     344 def get_extent(self, renderer):
#     345     """Return a tuple ``width, height, xdescent, ydescent`` of the box."""
# --> 346     w, h, xd, yd, offsets = self.get_extent_offsets(renderer)
#     347     return w, h, xd, yd
#
# File ~/anaconda3/envs/PNAS_codes/lib/python3.10/site-packages/matplotlib/offsetbox.py:471, in HPacker.get_extent_offsets(self, renderer)
#     468 pad = self.pad * dpicor
#     469 sep = self.sep * dpicor
# --> 471 whd_list = [c.get_extent(renderer)
#     472             for c in self.get_visible_children()]
#     474 if not whd_list:
#     475     return 2 * pad, 2 * pad, pad, pad, []
#
# File ~/anaconda3/envs/PNAS_codes/lib/python3.10/site-packages/matplotlib/offsetbox.py:471, in <listcomp>(.0)
#     468 pad = self.pad * dpicor
#     469 sep = self.sep * dpicor
# --> 471 whd_list = [c.get_extent(renderer)
#     472             for c in self.get_visible_children()]
#     474 if not whd_list:
#     475     return 2 * pad, 2 * pad, pad, pad, []
#
# File ~/anaconda3/envs/PNAS_codes/lib/python3.10/site-packages/matplotlib/offsetbox.py:346, in OffsetBox.get_extent(self, renderer)
#     344 def get_extent(self, renderer):
#     345     """Return a tuple ``width, height, xdescent, ydescent`` of the box."""
# --> 346     w, h, xd, yd, offsets = self.get_extent_offsets(renderer)
#     347     return w, h, xd, yd
#
# File ~/anaconda3/envs/PNAS_codes/lib/python3.10/site-packages/matplotlib/offsetbox.py:435, in VPacker.get_extent_offsets(self, renderer)
#     432         if isinstance(c, PackerBase) and c.mode == "expand":
#     433             c.set_width(self.width)
# --> 435 whd_list = [c.get_extent(renderer)
#     436             for c in self.get_visible_children()]
#     437 whd_list = [(w, h, xd, (h - yd)) for w, h, xd, yd in whd_list]
#     439 wd_list = [(w, xd) for w, h, xd, yd in whd_list]
#
# File ~/anaconda3/envs/PNAS_codes/lib/python3.10/site-packages/matplotlib/offsetbox.py:435, in <listcomp>(.0)
#     432         if isinstance(c, PackerBase) and c.mode == "expand":
#     433             c.set_width(self.width)
# --> 435 whd_list = [c.get_extent(renderer)
#     436             for c in self.get_visible_children()]
#     437 whd_list = [(w, h, xd, (h - yd)) for w, h, xd, yd in whd_list]
#     439 wd_list = [(w, xd) for w, h, xd, yd in whd_list]
#
# File ~/anaconda3/envs/PNAS_codes/lib/python3.10/site-packages/matplotlib/offsetbox.py:346, in OffsetBox.get_extent(self, renderer)
#     344 def get_extent(self, renderer):
#     345     """Return a tuple ``width, height, xdescent, ydescent`` of the box."""
# --> 346     w, h, xd, yd, offsets = self.get_extent_offsets(renderer)
#     347     return w, h, xd, yd
#
# File ~/anaconda3/envs/PNAS_codes/lib/python3.10/site-packages/matplotlib/offsetbox.py:471, in HPacker.get_extent_offsets(self, renderer)
#     468 pad = self.pad * dpicor
#     469 sep = self.sep * dpicor
# --> 471 whd_list = [c.get_extent(renderer)
#     472             for c in self.get_visible_children()]
#     474 if not whd_list:
#     475     return 2 * pad, 2 * pad, pad, pad, []
#
# File ~/anaconda3/envs/PNAS_codes/lib/python3.10/site-packages/matplotlib/offsetbox.py:471, in <listcomp>(.0)
#     468 pad = self.pad * dpicor
#     469 sep = self.sep * dpicor
# --> 471 whd_list = [c.get_extent(renderer)
#     472             for c in self.get_visible_children()]
#     474 if not whd_list:
#     475     return 2 * pad, 2 * pad, pad, pad, []
#
# File ~/anaconda3/envs/PNAS_codes/lib/python3.10/site-packages/matplotlib/offsetbox.py:785, in TextArea.get_extent(self, renderer)
#     784 def get_extent(self, renderer):
# --> 785     _, h_, d_ = renderer.get_text_width_height_descent(
#     786         "lp", self._text._fontproperties,
#     787         ismath="TeX" if self._text.get_usetex() else False)
#     789     bbox, info, yd = self._text._get_layout(renderer)
#     790     w, h = bbox.size
#
# File ~/anaconda3/envs/PNAS_codes/lib/python3.10/site-packages/matplotlib/backends/backend_agg.py:239, in RendererAgg.get_text_width_height_descent(self, s, prop, ismath)
#     236     return width, height, descent
#     238 font = self._prepare_font(prop)
# --> 239 font.set_text(s, 0.0, flags=get_hinting_flag())
#     240 w, h = font.get_width_height()  # width and height of unrotated string
#     241 d = font.get_descent()
#
# KeyboardInterrupt:

# %%
## plot u
fig, axs = plt.subplots(8,5, figsize=(15, 8), facecolor='w', edgecolor='k')
fig.subplots_adjust(hspace = .5, wspace=.5)

axs = axs.ravel()


for i in range(outer_steps):
    u = ds.u[i]
    xarray.plot.pcolormesh(u, 'x', 'y',cmap=seaborn.cm.rocket, col_wrap=4,ax=axs[i],robust=True);
# Out:
# /var/tmp/pbs.7024460.pbs/ipykernel_361940/829526412.py:10: DeprecationWarning: Using positional arguments is deprecated for plot methods, use keyword arguments instead.
#   xarray.plot.pcolormesh(u, 'x', 'y',cmap=seaborn.cm.rocket, col_wrap=4,ax=axs[i],robust=True);
# /var/tmp/pbs.7024460.pbs/ipykernel_361940/829526412.py:10: DeprecationWarning: Using positional arguments is deprecated for plot methods, use keyword arguments instead.
#   xarray.plot.pcolormesh(u, 'x', 'y',cmap=seaborn.cm.rocket, col_wrap=4,ax=axs[i],robust=True);
# /var/tmp/pbs.7024460.pbs/ipykernel_361940/829526412.py:10: DeprecationWarning: Using positional arguments is deprecated for plot methods, use keyword arguments instead.
#   xarray.plot.pcolormesh(u, 'x', 'y',cmap=seaborn.cm.rocket, col_wrap=4,ax=axs[i],robust=True);
# /var/tmp/pbs.7024460.pbs/ipykernel_361940/829526412.py:10: DeprecationWarning: Using positional arguments is deprecated for plot methods, use keyword arguments instead.
#   xarray.plot.pcolormesh(u, 'x', 'y',cmap=seaborn.cm.rocket, col_wrap=4,ax=axs[i],robust=True);
# /var/tmp/pbs.7024460.pbs/ipykernel_361940/829526412.py:10: DeprecationWarning: Using positional arguments is deprecated for plot methods, use keyword arguments instead.
#   xarray.plot.pcolormesh(u, 'x', 'y',cmap=seaborn.cm.rocket, col_wrap=4,ax=axs[i],robust=True);
# /var/tmp/pbs.7024460.pbs/ipykernel_361940/829526412.py:10: DeprecationWarning: Using positional arguments is deprecated for plot methods, use keyword arguments instead.
#   xarray.plot.pcolormesh(u, 'x', 'y',cmap=seaborn.cm.rocket, col_wrap=4,ax=axs[i],robust=True);
# /var/tmp/pbs.7024460.pbs/ipykernel_361940/829526412.py:10: DeprecationWarning: Using positional arguments is deprecated for plot methods, use keyword arguments instead.
#   xarray.plot.pcolormesh(u, 'x', 'y',cmap=seaborn.cm.rocket, col_wrap=4,ax=axs[i],robust=True);
# /var/tmp/pbs.7024460.pbs/ipykernel_361940/829526412.py:10: DeprecationWarning: Using positional arguments is deprecated for plot methods, use keyword arguments instead.
#   xarray.plot.pcolormesh(u, 'x', 'y',cmap=seaborn.cm.rocket, col_wrap=4,ax=axs[i],robust=True);
# /var/tmp/pbs.7024460.pbs/ipykernel_361940/829526412.py:10: DeprecationWarning: Using positional arguments is deprecated for plot methods, use keyword arguments instead.
#   xarray.plot.pcolormesh(u, 'x', 'y',cmap=seaborn.cm.rocket, col_wrap=4,ax=axs[i],robust=True);
# /var/tmp/pbs.7024460.pbs/ipykernel_361940/829526412.py:10: DeprecationWarning: Using positional arguments is deprecated for plot methods, use keyword arguments instead.
#   xarray.plot.pcolormesh(u, 'x', 'y',cmap=seaborn.cm.rocket, col_wrap=4,ax=axs[i],robust=True);
# /var/tmp/pbs.7024460.pbs/ipykernel_361940/829526412.py:10: DeprecationWarning: Using positional arguments is deprecated for plot methods, use keyword arguments instead.
#   xarray.plot.pcolormesh(u, 'x', 'y',cmap=seaborn.cm.rocket, col_wrap=4,ax=axs[i],robust=True);
# /var/tmp/pbs.7024460.pbs/ipykernel_361940/829526412.py:10: DeprecationWarning: Using positional arguments is deprecated for plot methods, use keyword arguments instead.
#   xarray.plot.pcolormesh(u, 'x', 'y',cmap=seaborn.cm.rocket, col_wrap=4,ax=axs[i],robust=True);
# /var/tmp/pbs.7024460.pbs/ipykernel_361940/829526412.py:10: DeprecationWarning: Using positional arguments is deprecated for plot methods, use keyword arguments instead.
#   xarray.plot.pcolormesh(u, 'x', 'y',cmap=seaborn.cm.rocket, col_wrap=4,ax=axs[i],robust=True);
# /var/tmp/pbs.7024460.pbs/ipykernel_361940/829526412.py:10: DeprecationWarning: Using positional arguments is deprecated for plot methods, use keyword arguments instead.
#   xarray.plot.pcolormesh(u, 'x', 'y',cmap=seaborn.cm.rocket, col_wrap=4,ax=axs[i],robust=True);
# /var/tmp/pbs.7024460.pbs/ipykernel_361940/829526412.py:10: DeprecationWarning: Using positional arguments is deprecated for plot methods, use keyword arguments instead.
#   xarray.plot.pcolormesh(u, 'x', 'y',cmap=seaborn.cm.rocket, col_wrap=4,ax=axs[i],robust=True);
# /var/tmp/pbs.7024460.pbs/ipykernel_361940/829526412.py:10: DeprecationWarning: Using positional arguments is deprecated for plot methods, use keyword arguments instead.
#   xarray.plot.pcolormesh(u, 'x', 'y',cmap=seaborn.cm.rocket, col_wrap=4,ax=axs[i],robust=True);
# /var/tmp/pbs.7024460.pbs/ipykernel_361940/829526412.py:10: DeprecationWarning: Using positional arguments is deprecated for plot methods, use keyword arguments instead.
#   xarray.plot.pcolormesh(u, 'x', 'y',cmap=seaborn.cm.rocket, col_wrap=4,ax=axs[i],robust=True);
# /var/tmp/pbs.7024460.pbs/ipykernel_361940/829526412.py:10: DeprecationWarning: Using positional arguments is deprecated for plot methods, use keyword arguments instead.
#   xarray.plot.pcolormesh(u, 'x', 'y',cmap=seaborn.cm.rocket, col_wrap=4,ax=axs[i],robust=True);
# /var/tmp/pbs.7024460.pbs/ipykernel_361940/829526412.py:10: DeprecationWarning: Using positional arguments is deprecated for plot methods, use keyword arguments instead.
#   xarray.plot.pcolormesh(u, 'x', 'y',cmap=seaborn.cm.rocket, col_wrap=4,ax=axs[i],robust=True);
# /var/tmp/pbs.7024460.pbs/ipykernel_361940/829526412.py:10: DeprecationWarning: Using positional arguments is deprecated for plot methods, use keyword arguments instead.
#   xarray.plot.pcolormesh(u, 'x', 'y',cmap=seaborn.cm.rocket, col_wrap=4,ax=axs[i],robust=True);
# /var/tmp/pbs.7024460.pbs/ipykernel_361940/829526412.py:10: DeprecationWarning: Using positional arguments is deprecated for plot methods, use keyword arguments instead.
#   xarray.plot.pcolormesh(u, 'x', 'y',cmap=seaborn.cm.rocket, col_wrap=4,ax=axs[i],robust=True);
# /var/tmp/pbs.7024460.pbs/ipykernel_361940/829526412.py:10: DeprecationWarning: Using positional arguments is deprecated for plot methods, use keyword arguments instead.
#   xarray.plot.pcolormesh(u, 'x', 'y',cmap=seaborn.cm.rocket, col_wrap=4,ax=axs[i],robust=True);
# /var/tmp/pbs.7024460.pbs/ipykernel_361940/829526412.py:10: DeprecationWarning: Using positional arguments is deprecated for plot methods, use keyword arguments instead.
#   xarray.plot.pcolormesh(u, 'x', 'y',cmap=seaborn.cm.rocket, col_wrap=4,ax=axs[i],robust=True);
# /var/tmp/pbs.7024460.pbs/ipykernel_361940/829526412.py:10: DeprecationWarning: Using positional arguments is deprecated for plot methods, use keyword arguments instead.
#   xarray.plot.pcolormesh(u, 'x', 'y',cmap=seaborn.cm.rocket, col_wrap=4,ax=axs[i],robust=True);
# /var/tmp/pbs.7024460.pbs/ipykernel_361940/829526412.py:10: DeprecationWarning: Using positional arguments is deprecated for plot methods, use keyword arguments instead.
#   xarray.plot.pcolormesh(u, 'x', 'y',cmap=seaborn.cm.rocket, col_wrap=4,ax=axs[i],robust=True);
# /var/tmp/pbs.7024460.pbs/ipykernel_361940/829526412.py:10: DeprecationWarning: Using positional arguments is deprecated for plot methods, use keyword arguments instead.
#   xarray.plot.pcolormesh(u, 'x', 'y',cmap=seaborn.cm.rocket, col_wrap=4,ax=axs[i],robust=True);
# /var/tmp/pbs.7024460.pbs/ipykernel_361940/829526412.py:10: DeprecationWarning: Using positional arguments is deprecated for plot methods, use keyword arguments instead.
#   xarray.plot.pcolormesh(u, 'x', 'y',cmap=seaborn.cm.rocket, col_wrap=4,ax=axs[i],robust=True);
# /var/tmp/pbs.7024460.pbs/ipykernel_361940/829526412.py:10: DeprecationWarning: Using positional arguments is deprecated for plot methods, use keyword arguments instead.
#   xarray.plot.pcolormesh(u, 'x', 'y',cmap=seaborn.cm.rocket, col_wrap=4,ax=axs[i],robust=True);
# /var/tmp/pbs.7024460.pbs/ipykernel_361940/829526412.py:10: DeprecationWarning: Using positional arguments is deprecated for plot methods, use keyword arguments instead.
#   xarray.plot.pcolormesh(u, 'x', 'y',cmap=seaborn.cm.rocket, col_wrap=4,ax=axs[i],robust=True);
# /var/tmp/pbs.7024460.pbs/ipykernel_361940/829526412.py:10: DeprecationWarning: Using positional arguments is deprecated for plot methods, use keyword arguments instead.
#   xarray.plot.pcolormesh(u, 'x', 'y',cmap=seaborn.cm.rocket, col_wrap=4,ax=axs[i],robust=True);
# /var/tmp/pbs.7024460.pbs/ipykernel_361940/829526412.py:10: DeprecationWarning: Using positional arguments is deprecated for plot methods, use keyword arguments instead.
#   xarray.plot.pcolormesh(u, 'x', 'y',cmap=seaborn.cm.rocket, col_wrap=4,ax=axs[i],robust=True);
# /var/tmp/pbs.7024460.pbs/ipykernel_361940/829526412.py:10: DeprecationWarning: Using positional arguments is deprecated for plot methods, use keyword arguments instead.
#   xarray.plot.pcolormesh(u, 'x', 'y',cmap=seaborn.cm.rocket, col_wrap=4,ax=axs[i],robust=True);
# /var/tmp/pbs.7024460.pbs/ipykernel_361940/829526412.py:10: DeprecationWarning: Using positional arguments is deprecated for plot methods, use keyword arguments instead.
#   xarray.plot.pcolormesh(u, 'x', 'y',cmap=seaborn.cm.rocket, col_wrap=4,ax=axs[i],robust=True);
# /var/tmp/pbs.7024460.pbs/ipykernel_361940/829526412.py:10: DeprecationWarning: Using positional arguments is deprecated for plot methods, use keyword arguments instead.
#   xarray.plot.pcolormesh(u, 'x', 'y',cmap=seaborn.cm.rocket, col_wrap=4,ax=axs[i],robust=True);
# /var/tmp/pbs.7024460.pbs/ipykernel_361940/829526412.py:10: DeprecationWarning: Using positional arguments is deprecated for plot methods, use keyword arguments instead.
#   xarray.plot.pcolormesh(u, 'x', 'y',cmap=seaborn.cm.rocket, col_wrap=4,ax=axs[i],robust=True);
# /var/tmp/pbs.7024460.pbs/ipykernel_361940/829526412.py:10: DeprecationWarning: Using positional arguments is deprecated for plot methods, use keyword arguments instead.
#   xarray.plot.pcolormesh(u, 'x', 'y',cmap=seaborn.cm.rocket, col_wrap=4,ax=axs[i],robust=True);
# /var/tmp/pbs.7024460.pbs/ipykernel_361940/829526412.py:10: DeprecationWarning: Using positional arguments is deprecated for plot methods, use keyword arguments instead.
#   xarray.plot.pcolormesh(u, 'x', 'y',cmap=seaborn.cm.rocket, col_wrap=4,ax=axs[i],robust=True);
# /var/tmp/pbs.7024460.pbs/ipykernel_361940/829526412.py:10: DeprecationWarning: Using positional arguments is deprecated for plot methods, use keyword arguments instead.
#   xarray.plot.pcolormesh(u, 'x', 'y',cmap=seaborn.cm.rocket, col_wrap=4,ax=axs[i],robust=True);
# /var/tmp/pbs.7024460.pbs/ipykernel_361940/829526412.py:10: DeprecationWarning: Using positional arguments is deprecated for plot methods, use keyword arguments instead.
#   xarray.plot.pcolormesh(u, 'x', 'y',cmap=seaborn.cm.rocket, col_wrap=4,ax=axs[i],robust=True);
# /var/tmp/pbs.7024460.pbs/ipykernel_361940/829526412.py:10: DeprecationWarning: Using positional arguments is deprecated for plot methods, use keyword arguments instead.
#   xarray.plot.pcolormesh(u, 'x', 'y',cmap=seaborn.cm.rocket, col_wrap=4,ax=axs[i],robust=True);

# %%
## plot v
fig, axs = plt.subplots(4,5, figsize=(15, 8), facecolor='w', edgecolor='k')
fig.subplots_adjust(hspace = .5, wspace=.5)

axs = axs.ravel()


for i in range(outer_steps):
    v = ds.v[i]
    xarray.plot.pcolormesh(v, 'x', 'y',cmap=seaborn.cm.rocket, col_wrap=4,ax=axs[i],robust=True);

# %%
fig, axs = plt.subplots(1,1, figsize=(15, 8), facecolor='w', edgecolor='k')

xarray.plot.pcolormesh(ds.u[0], 'x', 'y',cmap=seaborn.cm.rocket,robust=True, ax = axs);

# %%
## calculate and plot vorticity
def vorticity(ds):
  return (ds.v.differentiate('x') - ds.u.differentiate('y')).rename('vorticity')

(ds.pipe(vorticity)
 .plot.imshow(col='time', cmap=seaborn.cm.icefire, robust=True, col_wrap=5));

# %%
## quiver plot of velocity
fig, axs = plt.subplots(4,5, figsize=(17, 13), facecolor='w', edgecolor='k')
fig.subplots_adjust(hspace = .4, wspace=.5)

axs = axs.ravel()
for i in range(outer_steps):
    ds_plot = ds.isel(time=i)
    downsample_factor = 4 #divides by this
    ds_plot = ds_plot.coarsen(x=downsample_factor*2).mean().coarsen(y=downsample_factor).mean()
    ds_plot.plot.quiver(x='x', y='y', u='u', v='v', ax = axs[i], infer_intervals=True)

# %%
fig, axs = plt.subplots(1,1, figsize=(15, 8), facecolor='w', edgecolor='k')

#xarray.plot.pcolormesh(ds.u[19], 'x', 'y',cmap=seaborn.cm.rocket,robust=True, ax = axs);

ds_plot = ds.isel(time=5000) ## change this depending on what we want to plot

downsample_factor = 4 #divides by this
ds_plot = ds_plot.coarsen(x=downsample_factor*2).mean().coarsen(y=downsample_factor).mean()

ds_plot.plot.quiver(x='x', y='y', u='u', v='v', ax = axs, infer_intervals=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [4], line 10
#       7 downsample_factor = 4 #divides by this
#       8 ds_plot = ds_plot.coarsen(x=downsample_factor*2).mean().coarsen(y=downsample_factor).mean()
# ---> 10 ds_plot.plot.quiver(x='x', y='y', u='u', v='v', ax = axs, infer_intervals=True)
#
# File ~/anaconda3/envs/PNAS_codes/lib/python3.10/site-packages/xarray/plot/accessor.py:1186, in DatasetPlotAccessor.quiver(self, *args, **kwargs)
#    1184 @functools.wraps(dataset_plot.quiver)
#    1185 def quiver(self, *args, **kwargs) -> Quiver | FacetGrid:
# -> 1186     return dataset_plot.quiver(self._ds, *args, **kwargs)
#
# File ~/anaconda3/envs/PNAS_codes/lib/python3.10/site-packages/xarray/plot/dataset_plot.py:260, in _dsplot.<locals>.newplotfunc(***failed resolving arguments***)
#     254 if (u is not None or v is not None) and plotfunc.__name__ not in (
#     255     "quiver",
#     256     "streamplot",
#     257 ):
#     258     raise ValueError("u, v are only allowed for quiver or streamplot plots.")
# --> 260 primitive = plotfunc(
#     261     ds=ds,
#     262     x=x,
#     263     y=y,
#     264     ax=ax,
#     265     u=u,
#     266     v=v,
#     267     hue=hue,
#     268     hue_style=hue_style,
#     269     cmap_params=cmap_params_subset,
#     270     **kwargs,
#     271 )
#     273 if _is_facetgrid:  # if this was called from Facetgrid.map_dataset,
#     274     return primitive  # finish here. Else, make labels
#
# File ~/anaconda3/envs/PNAS_codes/lib/python3.10/site-packages/xarray/plot/dataset_plot.py:468, in quiver(ds, x, y, ax, u, v, **kwargs)
#     466 kwargs.pop("hue_style")
#     467 kwargs.setdefault("pivot", "middle")
# --> 468 hdl = ax.quiver(*args, **kwargs, **cmap_params)
#     469 return hdl
#
# File ~/anaconda3/envs/PNAS_codes/lib/python3.10/site-packages/matplotlib/__init__.py:1423, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1420 @functools.wraps(func)
#    1421 def inner(ax, *args, data=None, **kwargs):
#    1422     if data is None:
# -> 1423         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1425     bound = new_sig.bind(ax, *args, **kwargs)
#    1426     auto_label = (bound.arguments.get(label_namer)
#    1427                   or bound.kwargs.get(label_namer))
#
# File ~/anaconda3/envs/PNAS_codes/lib/python3.10/site-packages/matplotlib/axes/_axes.py:5103, in Axes.quiver(self, *args, **kwargs)
#    5101 # Make sure units are handled for x and y values
#    5102 args = self._quiver_units(args, kwargs)
# -> 5103 q = mquiver.Quiver(self, *args, **kwargs)
#    5104 self.add_collection(q, autolim=True)
#    5105 self._request_autoscale_view()
#
# File ~/anaconda3/envs/PNAS_codes/lib/python3.10/site-packages/matplotlib/quiver.py:490, in Quiver.__init__(self, ax, scale, headwidth, headlength, headaxislength, minshaft, minlength, units, scale_units, angles, width, color, pivot, *args, **kwargs)
#     483 """
#     484 The constructor takes one required argument, an Axes
#     485 instance, followed by the args and kwargs described
#     486 by the following pyplot interface documentation:
#     487 %s
#     488 """
#     489 self._axes = ax  # The attr actually set by the Artist.axes property.
# --> 490 X, Y, U, V, C = _parse_args(*args, caller_name='quiver()')
#     491 self.X = X
#     492 self.Y = Y
#
# File ~/anaconda3/envs/PNAS_codes/lib/python3.10/site-packages/matplotlib/quiver.py:435, in _parse_args(caller_name, *args)
#     431 else:
#     432     raise TypeError(f'{caller_name} takes 2-5 positional arguments but '
#     433                     f'{len_args} were given')
# --> 435 nr, nc = (1, U.shape[0]) if U.ndim == 1 else U.shape
#     437 if X is not None:
#     438     X = X.ravel()
#
# ValueError: too many values to unpack (expected 2)

# %%
def vel_at_middle_of_channel(ds, ySize,xSize):
    return ds.isel(x= int(np.floor(xSize/3))).isel(y= int(np.floor(ySize/3)))

ySize = len(ds.y.values)
xSize = len(ds.x.values)

du = ds.u
u = du.pipe(vel_at_middle_of_channel,ySize,xSize)
dv = ds.v
v = dv.pipe(vel_at_middle_of_channel,ySize,xSize)

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 10000, x: 1080, y: 256, sample: 1)
# Coordinates:
#   * time     (time) float64 0.03704 0.07407 0.1111 0.1481 ... 370.3 370.3 370.4
#   * x        (x) float32 0.003704 0.01111 0.01852 0.02593 ... 7.981 7.989 7.996
#   * y        (y) float32 0.003906 0.01172 0.01953 0.02734 ... 1.98 1.988 1.996
#   * sample   (sample) int32 0
# Data variables:
#     u        (sample, time, x, y) float32 dask.array<chunksize=(1, 90, 1080, 256), meta=np.ndarray>
#     v        (sample, time, x, y) float32 dask.array<chunksize=(1, 90, 1080, 256), meta=np.ndarray>

# %%
fig, axs = plt.subplots(1,1, figsize=(15, 8), facecolor='w', edgecolor='k')

xarray.plot.pcolormesh(ds.u, 'x', 'y',cmap=seaborn.cm.rocket,robust=True, ax = axs);
# Out:
# /var/tmp/pbs.7028797.pbs/ipykernel_196440/3394327978.py:3: DeprecationWarning: Using positional arguments is deprecated for plot methods, use keyword arguments instead.
#   xarray.plot.pcolormesh(ds.isel(time=200).u, 'x', 'y',cmap=seaborn.cm.rocket,robust=True, ax = axs);
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [10], line 3
#       1 fig, axs = plt.subplots(1,1, figsize=(15, 8), facecolor='w', edgecolor='k')
# ----> 3 xarray.plot.pcolormesh(ds.isel(time=200).u, 'x', 'y',cmap=seaborn.cm.rocket,robust=True, ax = axs);
#
# File ~/anaconda3/envs/PNAS_codes/lib/python3.10/site-packages/xarray/plot/dataarray_plot.py:1568, in _plot2d.<locals>.newplotfunc(***failed resolving arguments***)
#    1565     dims = yx_dims + tuple(d for d in darray.dims if d not in yx_dims)
#    1567 if dims != darray.dims:
# -> 1568     darray = darray.transpose(*dims, transpose_coords=True)
#    1570 # better to pass the ndarrays directly to plotting functions
#    1571 xvalnp = xval.to_numpy()
#
# File ~/anaconda3/envs/PNAS_codes/lib/python3.10/site-packages/xarray/core/dataarray.py:2915, in DataArray.transpose(self, transpose_coords, missing_dims, *dims)
#    2882 """Return a new DataArray object with transposed dimensions.
#    2883
#    2884 Parameters
#    (...)
#    2912 Dataset.transpose
#    2913 """
#    2914 if dims:
# -> 2915     dims = tuple(utils.infix_dims(dims, self.dims, missing_dims))
#    2916 variable = self.variable.transpose(*dims)
#    2917 if transpose_coords:
#
# File ~/anaconda3/envs/PNAS_codes/lib/python3.10/site-packages/xarray/core/utils.py:817, in infix_dims(dims_supplied, dims_all, missing_dims)
#     815 existing_dims = drop_missing_dims(dims_supplied, dims_all, missing_dims)
#     816 if set(existing_dims) ^ set(dims_all):
# --> 817     raise ValueError(
#     818         f"{dims_supplied} must be a permuted list of {dims_all}, unless `...` is included"
#     819     )
#     820 yield from existing_dims
#
# ValueError: ('y', 'x') must be a permuted list of ('sample', 'x', 'y'), unless `...` is included

# %%
ds.isel(time=7000).u.values

# %%
outer_steps

# %%
# filtering
u = u[:6100]
v = v[:6100]
total_sim_time = total_sim_time*(6100/10000)

# %%
total_sim_time

# %%
(outer_steps/total_sim_time)/2

# %%
#welch's method
f, Pxx_den = scipy.signal.welch(u,(outer_steps/total_sim_time))
plt.loglog(f, Pxx_den)
#plt.ylim([1e-7, 1e2])
plt.xlabel('frequency [Hz]')
plt.ylabel('PSD [V**2/Hz]')
plt.show()

# %%
#welch's method
f, Pxx_den = scipy.signal.welch(v,(outer_steps/total_sim_time))
plt.loglog(f, Pxx_den)
#plt.ylim([1e-7, 1e2])
plt.xlabel('frequency [Hz]')
plt.ylabel('PSD [V**2/Hz]')
plt.show()

# %%
#welch's method for kinetic energy
ek = np.sqrt((u**2 + v**2))
f, Pxx_den = scipy.signal.welch(ek,(outer_steps/total_sim_time))
plt.loglog(f, Pxx_den)
#plt.ylim([1e-7, 1e2])
plt.xlabel('frequency [Hz]')
plt.ylabel('PSD [V**2/Hz]')
plt.show()

# %%
ds

# %%
## plot grid

x = ds.x.values.flatten()
y = ds.y.values.flatten()

xgrid,ygrid = np.meshgrid(x,y)

# %%
plt.figure(figsize=(13, 8))
plt.scatter(xgrid,ygrid,1)
plt.show()
